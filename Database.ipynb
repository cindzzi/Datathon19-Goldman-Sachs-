# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import psycopg2
import sqlite3
import sqlalchemy

# %%
data = "justTaco.csv"
data_df = pd.read_csv(data)
data_df.head()
# Out:
#    index              Address  \
# 0    815         511 S 8th St
# 1   1185  1118 League Line Rd
# 2   1222    78480 Highway 111
# 3   1354  840 E Whittier Blvd
# 4   1509   3450 N Lincoln Ave
#
#                                           Categories       City  \
# 0  Vegetarian / Vegan Restaurant,Caf,American Res...  Sheboygan
# 1  Mexican Restaurant,Latin American Restaurants,...     Conroe
# 2  Restaurant,Mexican Restaurant and Road,Mexican...  La Quinta
# 3                                 Mexican Restaurant   La Habra
# 4                                 Mexican Restaurant    Chicago
#
#                    Cuisines   Menu                        Restaurants  \
# 0                   Burgers  Tacos                      Field to Fork
# 1       Mexican Restaurants  Tacos  Mama Juanita's Mexican Restaurant
# 2                   Mexican  Tacos                Las Casuelas Quinta
# 3               Restaurants  Tacos                           El Cholo
# ...

# %%
data2 = "justBurrito.csv"
data2_df = pd.read_csv(data2)
data2_df.head()
# Out:
#    index              Address  \
# 0   1223    78480 Highway 111
# 1   1510   3450 N Lincoln Ave
# 2   3914     40 Tramway Rd NE
# 3   4511        779 Route 340
# 4   5254  1231 Eastchester Dr
#
#                                           Categories         City  \
# 0  Restaurant,Mexican Restaurant and Road,Mexican...    La Quinta
# 1                                 Mexican Restaurant      Chicago
# 2                                 Mexican Restaurant  Albuquerque
# 3                                 Mexican Restaurant    Palisades
# 4  Mexican Restaurant and Burrito Place,Burrito P...   High Point
#
#                      Cuisines      Menu                Restaurants  Zip Code  \
# 0                     Mexican  Burritos        Las Casuelas Quinta     92253
# 1    Family Style Restaurants  Burritos      Fernando's Restaurant     60657
# 2      Mexican / Southwestern  Burritos   Sandiago's Mexican Grill     87122
# ...

# %%
data2_df['Province'].value_counts()
# Out:
# CA                              15
# NY                              10
# IL                               7
# GA                               5
# TX                               5
# MA                               3
# Nyc                              2
# NE                               2
# Saint Pete Beach                 2
# Edendale                         2
# MI                               2
# MN                               2
# NJ                               2
# RI                               1
# Los Feliz                        1
# West Conshohocken                1
# TN                               1
# Hunter Army Air Field            1
# NV                               1
# CT                               1
# Palm Springs Municipal Airpo     1
# Wedgwood                         1
# CO                               1
# Playa Vista                      1
# North Miami Beach                1
# ME                               1
# WI                               1
# ...

# %%
data_df['Province'].value_counts()
# Out:
# CA                              54
# IL                              14
# TX                              13
# CO                              10
# MN                               7
# PA                               7
# RI                               6
# VA                               6
# NY                               6
# IA                               5
# NV                               5
# MA                               5
# MI                               5
# FL                               5
# WI                               4
# NJ                               4
# AZ                               4
# MD                               4
# DC                               4
# Nyc                              3
# LA                               3
# MO                               3
# Manhattan                        3
# NM                               2
# ME                               2
# GA                               2
# NE                               2
# ...

# %%
type(data_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Set x axis and tick locations
x_axis = np.arange(len(data_df['City']))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, data_df["Province"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, data_df["City"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x11a7b9fd0>,
# ...
#  <a list of 220 Text xticklabel objects>)

# %%
x_axis = data["4 3"]
y_axis = data1['conn']
labels = "Province"

plt.figure(figsize=(20,10))
plt.scatter(x_axis, y_axis, marker="0", c = "pink", edgecolors="black", s=80, alpha=1)

plt.title("fdf")
plt.xlabel("skd")
plt.ylabel("dfd")
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-3c20149cb338> in <module>
# ----> 1 x_axis = data["4 3"]
#       2 y_axis = data1['conn']
#       3 labels = "Province"
#       4
#       5 plt.figure(figsize=(20,10))
#
# TypeError: string indices must be integers
